# %%
# %run ./utils

# %% [markdown]
# ## Extract

# %%
df_pin = get_dataframe_from_drive('038444ac863e.pin')
df_geo = get_dataframe_from_drive('038444ac863e.geo')
df_user = get_dataframe_from_drive('038444ac863e.user')

# %% [markdown]
# ## Transform

# %%
clean_df_pin = transform_pin_data(df_pin)
clean_df_geo = transform_geo_data(df_geo)
clean_df_user = transform_user_data(df_user)

# %% [markdown]
# ## Load

# %%
clean_df_pin.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("038444ac863e_clean_pin")
clean_df_geo.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("038444ac863e_clean_geo")
clean_df_user.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("038444ac863e_clean_user")
